# %% [markdown]
# <a href="https://colab.research.google.com/github/czokw1/ml-bootcamp/blob/main/supervised/01_basics/03_feature_extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Import Libraries

# %%
import pandas as pd
import numpy as np

import sklearn

# %% [markdown]
# #Get data

# %%
def fetch_financial_data(company='AMZN'):
  import pandas_datareader.data as web
  return web.DataReader(name=company,data_source='stooq')

df_raw = fetch_financial_data()

df_raw.head()
# Out:
#                 Open     High      Low    Close   Volume
# Date
# 2022-03-25  3280.000  3307.37  3245.00  3295.47  2454275
# 2022-03-24  3274.990  3282.37  3201.00  3272.99  2839903
# 2022-03-23  3274.100  3327.40  3253.74  3268.16  2790593
# 2022-03-22  3236.110  3323.34  3233.98  3297.78  3204306
# 2022-03-21  3222.415  3261.68  3191.06  3229.83  3326876

# %% [markdown]
# #Copy raw data

# %%
df = df_raw.copy()
df = df[:5]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5 entries, 2022-03-25 to 2022-03-21
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    5 non-null      float64
#  1   High    5 non-null      float64
#  2   Low     5 non-null      float64
#  3   Close   5 non-null      float64
#  4   Volume  5 non-null      int64
# dtypes: float64(4), int64(1)
# memory usage: 240.0 bytes

# %% [markdown]
# #Creating new variables

# %%
df['day'] = df.index.day
df['month'] = df.index.month
df['year'] = df.index.year
df
# Out:
#                 Open     High      Low    Close   Volume  day  month  year
# Date
# 2022-03-25  3280.000  3307.37  3245.00  3295.47  2454275   25      3  2022
# 2022-03-24  3274.990  3282.37  3201.00  3272.99  2839903   24      3  2022
# 2022-03-23  3274.100  3327.40  3253.74  3268.16  2790593   23      3  2022
# 2022-03-22  3236.110  3323.34  3233.98  3297.78  3204306   22      3  2022
# 2022-03-21  3222.415  3261.68  3191.06  3229.83  3326876   21      3  2022

# %% [markdown]
# #Creating constant variables

# %%
df = pd.DataFrame(data={'height':[175.,178.5,185.,184.5,183.,168.]})
df
# Out:
#    height
# 0   175.0
# 1   178.5
# 2   185.0
# 3   184.5
# 4   183.0
# 5   168.0

# %%
df['height_cat'] = pd.cut(x=df.height,bins=3)
df
# Out:
#    height          height_cat
# 0   175.0  (173.667, 179.333]
# 1   178.5  (173.667, 179.333]
# 2   185.0    (179.333, 185.0]
# 3   184.5    (179.333, 185.0]
# 4   183.0    (179.333, 185.0]
# 5   168.0  (167.983, 173.667]

# %%
df['height_cat'] = pd.cut(x=df.height,bins=(160,175,180,195))
df
# Out:
#    height  height_cat
# 0   175.0  (160, 175]
# 1   178.5  (175, 180]
# 2   185.0  (180, 195]
# 3   184.5  (180, 195]
# 4   183.0  (180, 195]
# 5   168.0  (160, 175]

# %%
df['height_cat'] = pd.cut(x=df.height,bins=(160,175,180,195), labels=['small','medium','heigh'])
df
# Out:
#    height height_cat
# 0   175.0      small
# 1   178.5     medium
# 2   185.0      heigh
# 3   184.5      heigh
# 4   183.0      heigh
# 5   168.0      small

# %%
pd.get_dummies(df,drop_first=True,prefix='height')
# Out:
#    height  height_medium  height_heigh
# 0   175.0              0             0
# 1   178.5              1             0
# 2   185.0              0             1
# 3   184.5              0             1
# 4   183.0              0             1
# 5   168.0              0             0

# %% [markdown]
# #Features extraction

# %%
df = pd.DataFrame(data={'lang':[['PL','ENG'],['GER','ENG','PL','FRA'],['RUS']]})
df
# Out:
#                   lang
# 0            [PL, ENG]
# 1  [GER, ENG, PL, FRA]
# 2                [RUS]

# %%
df['lang_number'] = df['lang'].apply(len)
df
# Out:
#                   lang  lang_number
# 0            [PL, ENG]            2
# 1  [GER, ENG, PL, FRA]            4
# 2                [RUS]            1

# %%
df['PL_flag'] = df['lang'].apply(lambda x: 1 if 'PL' in x else 0)
df
# Out:
#                   lang  lang_number  PL_flag
# 0            [PL, ENG]            2        1
# 1  [GER, ENG, PL, FRA]            4        1
# 2                [RUS]            1        0

# %%
df = pd.DataFrame(data={'website':['wp.pl','onet.pl','google.com']})
df
# Out:
#       website
# 0       wp.pl
# 1     onet.pl
# 2  google.com

# %%
df.website.str.split('.',expand=True)
# Out:
#         0    1
# 0      wp   pl
# 1    onet   pl
# 2  google  com

# %%
new  = df.website.str.split('.',expand=True)
df['portal'] =new[0]
df['extension'] = new[1]
df
# Out:
#       website  portal extension
# 0       wp.pl      wp        pl
# 1     onet.pl    onet        pl
# 2  google.com  google       com
